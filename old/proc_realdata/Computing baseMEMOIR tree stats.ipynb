# %%
import glob
import os

folder_path = "/Users/gc3045/laml2_experiments/proc_realdata/baseMemoir"
tree_files = glob.glob(os.path.join(folder_path, "*starting_tree.nwk"))

tree_objs = []
for f in tree_files:
    # print(os.path.basename(f))
    print(f)
    #tree_obj = Phylo.read(f, "nexus")
    #tree_objs.append(tree_obj)
# Out:
# /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/p78_starting_tree.nwk
# /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/p910_starting_tree.nwk
# /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/p4_starting_tree.nwk
# /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/p5_starting_tree.nwk
# /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/p6_starting_tree.nwk
# /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/p3_starting_tree.nwk
# /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/p2_starting_tree.nwk

# %%
# python ${scriptdir}/compare_two_trees.py --tree1 ${truetree} --tree2 ${esttree} | awk -F, '{ print $NF }'

# %%
! pip install dendropy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.5/459.5 kB 12.1 MB/s eta 0:00:00
# ...

# %%
! python /Users/gc3045/useful_scripts/compare_two_trees.py --tree1 /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/p2_starting_tree.nwk --tree2 /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/baseMemoir_runs/LAML2_p2_baseMem_trees.nwk | awk -F, '{ print $NF }'
# Out:
# 0.909091

# %%
! python /Users/gc3045/useful_scripts/compare_two_trees.py --tree1 /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/p3_starting_tree.nwk --tree2 /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/baseMemoir_runs/LAML2_p3_baseMem_trees.nwk | awk -F, '{ print $NF }'
# Out:
# 0.640000

# %%
! python /Users/gc3045/useful_scripts/compare_two_trees.py --tree1 /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/p4_starting_tree.nwk --tree2 /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/baseMemoir_runs/LAML2_p4_baseMem_trees.nwk | awk -F, '{ print $NF }'
# Out:
# 0.967742

# %%
! python /Users/gc3045/useful_scripts/compare_two_trees.py --tree1 /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/p5_starting_tree.nwk --tree2 /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/baseMemoir_runs/LAML2_p5_baseMem_trees.nwk | awk -F, '{ print $NF }'
# Out:
# 0.979592

# %%
! python /Users/gc3045/useful_scripts/compare_two_trees.py --tree1 /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/p6_starting_tree.nwk --tree2 /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/baseMemoir_runs/LAML2_p6_baseMem_trees.nwk | awk -F, '{ print $NF }'
# Out:
# 0.962963

# %%
! python /Users/gc3045/useful_scripts/compare_two_trees.py --tree1 /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/p78_starting_tree.nwk --tree2 /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/baseMemoir_runs/LAML2_p78_baseMem_trees.nwk | awk -F, '{ print $NF }'
# Out:
# 0.957746

# %%
! python /Users/gc3045/useful_scripts/compare_two_trees.py --tree1 /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/p910_starting_tree.nwk --tree2 /Users/gc3045/laml2_experiments/proc_realdata/baseMemoir/baseMemoir_runs/LAML2_p910_baseMem_trees.nwk | awk -F, '{ print $NF }'
# Out:
# 0.925373

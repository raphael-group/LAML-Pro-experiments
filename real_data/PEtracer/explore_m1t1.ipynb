# %%
import treedata

# %%
m1t1_fname = "/Users/gc3045/git/laml2-experiments/real_data/PEtracer/28473866/M1_tumor_tracing.h5td"
m3_fname = "/Users/gc3045/git/laml2-experiments/real_data/PEtracer/28473866/53269751_M3_tumor_tracing.h5td"
barcoded_tracing_clone1 = "/Users/gc3045/git/laml2-experiments/real_data/PEtracer/28473866/barcoded_tracing_clone_1.h5td"

# %%
m1t1_data = treedata.read_h5td(m1t1_fname)
m3_data = treedata.read_h5td(m3_fname)

# %%
barcoded_tracing_clone1_data = treedata.read_h5td(barcoded_tracing_clone1)

# %%
m1t1_data
# Out:
# TreeData object with n_obs × n_vars = 262062 × 124
#     obs: 'sample', 'cell', 'cellBC', 'fov', 'centroid_x', 'centroid_y', 'centroid_z', 'n_layers', 'volume', 'n_genes_by_counts', 'total_counts', 'cell_subtype', 'true_proportion', 'diffusion_proportion', 'background_proportion', 'total_density', 'tumor', 'tumor_boundary_dist', 'within_tumor', 'lung_boundary_dist', 'type', 'clone', 'detection_rate', 'tree', 'fitness', 'clade', 'character_dist_of_relatives', 'local_character_diversity', 'cell_neighborhood'
#     uns: 'cell_neighborhood_colors', 'cell_subtype_colors', 'clone_characters', 'within_tumor_colors'
#     obsm: 'X_resolVI', 'X_umap', 'celltype_module_scores', 'characters', 'resolvi_celltypes', 'spatial', 'spatial_grid', 'spatial_overlay', 'subtype_density'
#     layers: 'counts', 'generated_expression', 'normalized', 'scaled'
#     obst: '1', '1_collapsed', '2', '2_collapsed', '3', '3_collapsed', '4', '4_collapsed'

# %%
m1t1_data.obs
# Out:
#             sample    cell       cellBC  fov   centroid_x   centroid_y  \
# M1-1-16       M1-1      16      M1-1-16    0   937.433018   637.866146
# M1-1-20       M1-1      20      M1-1-20    0   913.218530   634.840285
# M1-1-34       M1-1      34      M1-1-34    0   964.877099   648.656377
# M1-1-55       M1-1      55      M1-1-55    0   897.913208   669.409893
# M1-1-57       M1-1      57      M1-1-57    0   918.717027   673.582191
# ...            ...     ...          ...  ...          ...          ...
# M1-4-119616   M1-4  119616  M1-4-119616  220  -828.295991 -4188.649701
# M1-4-119622   M1-4  119622  M1-4-119622  220 -1004.126165 -4314.593646
# M1-4-119623   M1-4  119623  M1-4-119623  220  -851.663220 -4311.116906
# M1-4-119626   M1-4  119626  M1-4-119626  220  -824.340556 -4236.717016
# M1-4-119631   M1-4  119631  M1-4-119631  220  -876.871961 -4327.522147
#
#              centroid_z  n_layers       volume  n_genes_by_counts  ...  \
# ...

# %%
m3_data
# Out:
# TreeData object with n_obs × n_vars = 145954 × 175
#     obs: 'sample', 'cell', 'cellBC', 'fov', 'centroid_x', 'centroid_y', 'centroid_z', 'n_layers', 'volume', 'n_genes_by_counts', 'total_counts', 'cell_subtype', 'true_proportion', 'diffusion_proportion', 'background_proportion', 'total_density', 'tumor', 'tumor_boundary_dist', 'within_tumor', 'lung_boundary_dist', 'type', 'clone', 'detection_rate', 'tree', 'fitness', 'clade', 'character_dist_of_relatives', 'local_character_diversity', 'hotspot_module', 'phase'
#     uns: 'clone_characters', 'clone_colors', 'hotspot_module_colors', 'within_tumor_colors'
#     obsm: 'X_resolVI', 'X_umap', 'characters', 'module_scores', 'resolvi_celltypes', 'spatial', 'spatial_grid', 'spatial_overlay', 'subtype_density'
#     layers: 'counts', 'generated_expression', 'normalized', 'scaled'
#     obst: '1', '1_collapsed'

# %%
m3_data.obs.columns
# Out:
# Index(['sample', 'cell', 'cellBC', 'fov', 'centroid_x', 'centroid_y',
#        'centroid_z', 'n_layers', 'volume', 'n_genes_by_counts', 'total_counts',
#        'cell_subtype', 'true_proportion', 'diffusion_proportion',
#        'background_proportion', 'total_density', 'tumor',
#        'tumor_boundary_dist', 'within_tumor', 'lung_boundary_dist', 'type',
#        'clone', 'detection_rate', 'tree', 'fitness', 'clade',
#        'character_dist_of_relatives', 'local_character_diversity',
#        'hotspot_module', 'phase'],
#       dtype='object')

# %%
barcoded_tracing_clone1_data
# Out:
# TreeData object with n_obs × n_vars = 9625 × 32288
#     obs: 'cellBC', 'sample', 'clone', 'type', 'puro', 'blast', 'tree', 'puro_clade', 'combined_clade', 'blast_clade'
#     var: 'mean_counts', 'total_counts'
#     obsm: 'blast_counts', 'characters', 'puro_counts'
#     obst: 'tree'
